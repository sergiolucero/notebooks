# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiolucero/notebooks/blob/main/PyCaret_Driv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --q pycaret

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

data = get_data('heart_disease')
model1 = setup(data = data, target = 'Disease')
# Out:
#                                Description             Value
# 0                               session_id               287
# 1                                   Target           Disease
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data         (270, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 8
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (188, 25)
# 12                    Transformed Test Set          (82, 25)
# 13                      Shuffle Train-Test              True
# ...

# %%
data = get_data('automobile')
from pycaret.regression import *
model2 = setup(data = data, target = 'price')
random_forest_r = create_model('rf')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     1733.6826  5.140589e+06  2267.2866  0.9179  0.1320  0.1140
# 1     1186.5386  2.798256e+06  1672.7987  0.9555  0.1268  0.0957
# 2     1642.0071  5.872338e+06  2423.2907  0.7217  0.1667  0.1357
# 3     2757.5098  2.218288e+07  4709.8706  0.7731  0.2193  0.1575
# 4     2269.1007  8.597210e+06  2932.1000  0.9184  0.1753  0.1464
# 5     1478.1085  5.805519e+06  2409.4645  0.9000  0.1370  0.0953
# 6     1333.0671  3.470995e+06  1863.0606  0.8469  0.1218  0.0988
# 7     2186.6962  8.842869e+06  2973.6962  0.4267  0.2288  0.1804
# 8      852.6199  1.128446e+06  1062.2835  0.8969  0.1112  0.0934
# 9      799.7415  1.356962e+06  1164.8872  0.9653  0.1203  0.0881
# Mean  1623.9072  6.519606e+06  2347.8739  0.8322  0.1539  0.1205
# SD     600.1424  5.802954e+06  1003.5411  0.1539  0.0400  0.0307

# %%
data
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 197         -1               95.0        volvo       gas      turbo
# 198         -1               95.0        volvo       gas        std
# 199         -1               95.0        volvo    diesel      turbo
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
chile = pd.read_csv('http://quant.cl/static/DATA/AUTOS/chileautos.csv.gz')

# %%
from pycaret.classification import *

model3 = setup(data = chile, target = 'precio')
random_forest_r = create_model('rf')
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            23:42:51
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                          Data Type
# Vehículo               Categorical
# Kilometraje                Numeric
# Color_Exterior         Categorical
# Transmisión            Categorical
# Puertas                Categorical
# Pasajeros              Categorical
# Litros_(motor)             Numeric
# Cilindros                  Numeric
# Combustible            Categorical
# Consumo                Categorical
# Región                 Categorical
# Ciudad                 Categorical
# Modelo                 Categorical
# Marca                  Categorical
# Ano_Modelo                 Numeric
# Grupo_de_Modelos       Categorical
# ConsumoUrbano              Numeric
# ...
